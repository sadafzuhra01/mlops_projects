# %% [markdown]
# ## Day-1 Python Programming

# %%
## syntax: how to write code

# %%
## semantics : what a code is supposed to do

# %%
## multiline comment : used in py file 
## """

## """

# %%
## case sensitivity 
name = "Sadaf"
Name = "Zuhra"
print(name) # Sadaf
print(Name) # Zuhra
# Out:
# Sadaf
# Zuhra

# %%
## indentation :equal to 4-space /one tab 
age = 25  # You can change this to any number
if age > 21:
    print("You are an adult")
# Out:
# You are an adult

# %%
## line continuation : \ 
total = 1+5+7+81+99+\
    50+31
print(total)
# Out:
# 274

# %%
## multiple statment in one line 
x= 5; y=23; z=66
print(x); (y); (z)
# Out:
# 5
# 66
