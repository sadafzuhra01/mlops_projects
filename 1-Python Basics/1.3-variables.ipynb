# %% [markdown]
# - variable assignment
# - naming convention
# - dynamic typing
# - & type conversion

# %%
a = 23 # integer
name = "Sadaf"#string
height = 5.2# float
is_adult = True# bolean

# %%
print (type(a))
print (type(name))
print (type(height))
print (type(is_adult))
## python is a dynamically typed language
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
var = 24
print(type(var))
var = "Eman"
print(type(var))
var = 5.1
print(type(var))
var = True
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
##type conversion
age ="23"
print(type(age))
age_1 =int(age)
print(type(age_1))
# Out:
# <class 'str'>
# <class 'int'>

# %%
## Naming convension 
## always use small letter , numbers and underscore

# %%
## input()function 
num_1 =int(input("Enter a number! "))
num_2 =int(input("Enter a number! "))

sum = num_1+num_2
diff =  num_1-num_2
mult = num_1*num_2
div = num_1/num_2

print(sum)
print(diff)
print(mult)
print(div)
# Out:
# 55
# 33
# 484
# 4.0

# %% [markdown]
# ## Basic data types
# - string
# - integer
# - boolean
# - float

# %%
##string
name = "Sadaf"

# %%
print(name.upper())
# Out:
# SADAF

# %%
##boolean 
x = True
y = True

# %%
## integer 
age = 23

# %%
##float 
height = 5.2
